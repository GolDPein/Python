# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
A = "interviewbit"

# %%
def getStrCount(A):
    finalStr = ""
    for a in A:
        if a in "aeiou":
            finalStr += a

    print(finalStr)

# %%
getStrCount("abcdye")
# Out:
# ae
